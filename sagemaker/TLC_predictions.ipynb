# %%
# %pip install -q awswrangler==3.* sagemaker==2.* boto3==1.* pyarrow==15.* scikit-learn==1.4.*

import os, json, math, boto3, awswrangler as wr, numpy as np, pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error, r2_score,
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
)
import sagemaker
from sagemaker import image_uris

region = "us-east-1"
sess = sagemaker.Session()
sm_client = boto3.client("sagemaker", region_name=region)
s3 = boto3.client("s3", region_name=region)
athena = boto3.client("athena", region_name=region)

role = sagemaker.get_execution_role()

ATHENA_WORKGROUP = "taxi-wg"
ATHENA_DB = "nyc_taxi"
ATHENA_OUTPUT = "s3://genai-taxi-athena-results-poc/athena/"
S3_BUCKET = "genai-taxi-curated-poc"
ARTIFACTS_PREFIX = "sagemaker/xgb-taxi"
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
sql = """
SELECT
  CAST(date_format(tpep_pickup_datetime, '%H') AS integer) AS pickup_hour,
  date_format(tpep_pickup_datetime, '%a') AS dow,
  COALESCE(passenger_count, 0) AS passenger_count,
  trip_distance,
  COALESCE(payment_type, 0) AS payment_type,
  fare_amount,
  tip_amount
FROM nyc_taxi.yellow_curated y
WHERE y.year = 2024
  AND y.month BETWEEN 7 AND 12
  AND fare_amount IS NOT NULL
  AND tip_amount IS NOT NULL
  AND trip_distance IS NOT NULL
"""

df = wr.athena.read_sql_query(
    sql=sql + " LIMIT 500000",
    database=ATHENA_DB,
    workgroup=ATHENA_WORKGROUP,
    s3_output=ATHENA_OUTPUT,
    ctas_approach=True
)

# %%
df.shape
df.head
# Out:
# <bound method NDFrame.head of         pickup_hour  dow  passenger_count  trip_distance  payment_type  \
# 0                 8  Sat                1           4.89             1
# 1                 8  Sat                1           1.72             1
# 2                 8  Sat                2           2.48             2
# 3                 8  Sat                1           2.47             1
# 4                 8  Sat                1           0.90             1
# ...             ...  ...              ...            ...           ...
# 499995           20  Thu                3           2.30             1
# 499996           20  Thu                1           0.00             1
# 499997           20  Thu                2          12.09             1
# 499998           20  Thu                1           3.63             1
# 499999           20  Thu                1           2.80             1
#
#         fare_amount  tip_amount
# 0              24.7        5.74
# 1               9.3        2.00
# 2              14.9        0.00
# 3              14.2        3.64
# 4               6.5        1.58
# ...             ...         ...
# 499995         13.5        4.60
# 499996         64.3       17.57
# 499997         52.7       11.39
# 499998         17.7        5.67
# 499999         16.3        4.70
#
# [500000 rows x 7 columns]>

# %%
import numpy as np, pandas as pd
from sklearn.model_selection import train_test_split

# Map day-of-week to 0..6
dow_map = {"Mon":0,"Tue":1,"Wed":2,"Thu":3,"Fri":4,"Sat":5,"Sun":6}
df["dow_idx"] = df["dow"].map(dow_map).fillna(0).astype(int)

# Light outlier caps (keeps training stable)
df = df[(df["fare_amount"]>=0)&(df["fare_amount"]<=200)
        &(df["trip_distance"]>=0)&(df["trip_distance"]<=50)
        &(df["tip_amount"]>=0)&(df["tip_amount"]<=100)]

FEATURES = ["pickup_hour","dow_idx","passenger_count","trip_distance","payment_type","fare_amount"]
X = df[FEATURES].astype(float)
y_reg = df["tip_amount"].astype(float)           # regression target
y_cls = (df["tip_amount"] > 0).astype(int)       # classification label

# Split once, reuse for both tasks (70/15/15)
X_train, X_temp, y_reg_train, y_reg_temp, y_cls_train, y_cls_temp = train_test_split(
    X, y_reg, y_cls, test_size=0.30, random_state=42
)
X_val, X_test, y_reg_val, y_reg_test, y_cls_val, y_cls_test = train_test_split(
    X_temp, y_reg_temp, y_cls_temp, test_size=0.50, random_state=42
)

len(X_train), len(X_val), len(X_test)
# Out:
# (343194, 73542, 73542)

# %%
import boto3
s3 = boto3.client("s3")
S3_BUCKET = "genai-taxi-curated-poc"
ARTIFACTS_PREFIX = "sagemaker/xgb-taxi"

def to_xgb_csv(X, y):
    arr = np.concatenate([y.values.reshape(-1,1), X.values], axis=1)
    return "\n".join([",".join(map(str,row)) for row in arr])

paths = {}
# Regression
for split, Xs, ys in [("train",X_train,y_reg_train), ("val",X_val,y_reg_val), ("test",X_test,y_reg_test)]:
    key = f"{ARTIFACTS_PREFIX}/regression/{split}.csv"
    s3.put_object(Bucket=S3_BUCKET, Key=key, Body=to_xgb_csv(Xs, ys).encode())
    paths.setdefault("reg", {})[split] = f"s3://{S3_BUCKET}/{key}"

# Classification
for split, Xs, ys in [("train",X_train,y_cls_train), ("val",X_val,y_cls_val), ("test",X_test,y_cls_test)]:
    key = f"{ARTIFACTS_PREFIX}/classification/{split}.csv"
    s3.put_object(Bucket=S3_BUCKET, Key=key, Body=to_xgb_csv(Xs, ys).encode())
    paths.setdefault("cls", {})[split] = f"s3://{S3_BUCKET}/{key}"

paths
# Out:
# {'reg': {'train': 's3://genai-taxi-curated-poc/sagemaker/xgb-taxi/regression/train.csv',
#   'val': 's3://genai-taxi-curated-poc/sagemaker/xgb-taxi/regression/val.csv',
#   'test': 's3://genai-taxi-curated-poc/sagemaker/xgb-taxi/regression/test.csv'},
#  'cls': {'train': 's3://genai-taxi-curated-poc/sagemaker/xgb-taxi/classification/train.csv',
#   'val': 's3://genai-taxi-curated-poc/sagemaker/xgb-taxi/classification/val.csv',
#   'test': 's3://genai-taxi-curated-poc/sagemaker/xgb-taxi/classification/test.csv'}}

# %%
import sagemaker
from sagemaker import image_uris
from sagemaker.inputs import TrainingInput

sess = sagemaker.Session()
role = sagemaker.get_execution_role()
region = sess.boto_region_name
container = image_uris.retrieve(framework="xgboost", region=region, version="1.7-1")

# Regression
reg_est = sagemaker.estimator.Estimator(
    image_uri=container, role=role, instance_count=1, instance_type="ml.m5.large",
    output_path=f"s3://{S3_BUCKET}/{ARTIFACTS_PREFIX}/regression/output", sagemaker_session=sess
)
reg_est.set_hyperparameters(
    objective="reg:squarederror", num_round=1000, max_depth=6, eta=0.1,
    subsample=0.8, colsample_bytree=0.8, eval_metric="rmse", early_stopping_rounds=25
)
reg_est.fit(
    {
        "train": TrainingInput(
            s3_data=paths["reg"]["train"],
            content_type="text/csv"
        ),
        "validation": TrainingInput(
            s3_data=paths["reg"]["val"],
            content_type="text/csv"
        ),
    },
    logs=True,
)
# Classification
cls_est = sagemaker.estimator.Estimator(
    image_uri=container, role=role, instance_count=1, instance_type="ml.m5.large",
    output_path=f"s3://{S3_BUCKET}/{ARTIFACTS_PREFIX}/classification/output", sagemaker_session=sess
)
cls_est.set_hyperparameters(
    objective="binary:logistic", num_round=1000, max_depth=6, eta=0.1,
    subsample=0.8, colsample_bytree=0.8, eval_metric="auc", early_stopping_rounds=25
)
cls_est.fit(
    {
        "train": TrainingInput(
            s3_data=paths["cls"]["train"],
            content_type="text/csv"
        ),
        "validation": TrainingInput(
            s3_data=paths["cls"]["val"],
            content_type="text/csv"
        ),
    },
    logs=True,
)
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2025-08-08-21-26-56-997
# 2025-08-08 21:26:58 Starting - Starting the training job...
# 2025-08-08 21:27:14 Starting - Preparing the instances for training...
# 2025-08-08 21:27:34 Downloading - Downloading input data...
# 2025-08-08 21:28:20 Downloading - Downloading the training image......
# 2025-08-08 21:29:26 Training - Training image download completed. Training in progress.../miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2025-08-08 21:29:29.594 ip-10-0-104-94.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-08-08 21:29:29.634 ip-10-0-104-94.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-08-08:21:29:30:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-08-08:21:29:30:INFO] Failed to parse hyperparameter eval_metric value rmse to Json.
# Returning the value itself
# [2025-08-08:21:29:30:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2025-08-08:21:29:30:INFO] No GPUs detected (normal if no gpus installed)
# [2025-08-08:21:29:30:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-08-08:21:29:30:INFO] Determined 0 GPU(s) available on the instance.
# [2025-08-08:21:29:30:INFO] Determined delimiter of CSV input is ','
# [2025-08-08:21:29:30:INFO] Determined delimiter of CSV input is ','
# [2025-08-08:21:29:30:INFO] File path /opt/ml/input/data/train of input files
# [2025-08-08:21:29:30:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2025-08-08:21:29:30:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv4674393010074255302
# [2025-08-08:21:29:30:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2025-08-08:21:29:30:INFO] Determined delimiter of CSV input is ','
# [2025-08-08:21:29:30:INFO] File path /opt/ml/input/data/validation of input files
# [2025-08-08:21:29:30:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2025-08-08:21:29:30:INFO] creating symlink between Path /opt/ml/input/data/validation/val.csv and destination /tmp/sagemaker_xgboost_input_data/val.csv8294650622407960073
# [2025-08-08:21:29:30:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2025-08-08:21:29:30:INFO] Determined delimiter of CSV input is ','
# [2025-08-08:21:29:30:INFO] Single node training.
# [2025-08-08:21:29:30:INFO] Train matrix has 343194 rows and 6 columns
# [2025-08-08:21:29:30:INFO] Validation matrix has 73542 rows
# [2025-08-08 21:29:30.339 ip-10-0-104-94.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-08-08 21:29:30.340 ip-10-0-104-94.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-08-08 21:29:30.341 ip-10-0-104-94.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2025-08-08 21:29:30.341 ip-10-0-104-94.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-08-08:21:29:30:INFO] Debug hook created from config
# /miniconda3/lib/python3.9/site-packages/xgboost/training.py:39: UserWarning: `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
#   warnings.warn(
# [0]#011train-rmse:5.05623#011validation-rmse:5.02139
# [2025-08-08 21:29:30.633 ip-10-0-104-94.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2025-08-08 21:29:30.636 ip-10-0-104-94.ec2.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [1]#011train-rmse:4.76348#011validation-rmse:4.72867
# [2]#011train-rmse:4.44864#011validation-rmse:4.41267
# [3]#011train-rmse:4.16109#011validation-rmse:4.12528
# [4]#011train-rmse:3.91202#011validation-rmse:3.87597
# [5]#011train-rmse:3.74819#011validation-rmse:3.71188
# [6]#011train-rmse:3.55586#011validation-rmse:3.51896
# [7]#011train-rmse:3.40171#011validation-rmse:3.36365
# [8]#011train-rmse:3.30553#011validation-rmse:3.26722
# [9]#011train-rmse:3.19097#011validation-rmse:3.15210
# [10]#011train-rmse:3.12379#011validation-rmse:3.08508
# [11]#011train-rmse:3.02799#011validation-rmse:2.98940
# [12]#011train-rmse:2.97534#011validation-rmse:2.93745
# [13]#011train-rmse:2.93722#011validation-rmse:2.89951
# [14]#011train-rmse:2.88059#011validation-rmse:2.84281
# [15]#011train-rmse:2.84968#011validation-rmse:2.81246
# [16]#011train-rmse:2.79488#011validation-rmse:2.75857
# [17]#011train-rmse:2.75307#011validation-rmse:2.71787
# [18]#011train-rmse:2.71902#011validation-rmse:2.68378
# [19]#011train-rmse:2.69081#011validation-rmse:2.65550
# [20]#011train-rmse:2.66294#011validation-rmse:2.62818
# [21]#011train-rmse:2.65208#011validation-rmse:2.61747
# [22]#011train-rmse:2.63452#011validation-rmse:2.60038
# [23]#011train-rmse:2.62650#011validation-rmse:2.59341
# [24]#011train-rmse:2.60772#011validation-rmse:2.57541
# [25]#011train-rmse:2.59839#011validation-rmse:2.56726
# [26]#011train-rmse:2.58857#011validation-rmse:2.55832
# [27]#011train-rmse:2.58125#011validation-rmse:2.55179
# [28]#011train-rmse:2.57358#011validation-rmse:2.54495
# [29]#011train-rmse:2.56407#011validation-rmse:2.53630
# [30]#011train-rmse:2.55814#011validation-rmse:2.53138
# [31]#011train-rmse:2.55569#011validation-rmse:2.52975
# [32]#011train-rmse:2.55004#011validation-rmse:2.52460
# [33]#011train-rmse:2.54826#011validation-rmse:2.52358
# [34]#011train-rmse:2.54367#011validation-rmse:2.51986
# [35]#011train-rmse:2.54081#011validation-rmse:2.51735
# [36]#011train-rmse:2.53835#011validation-rmse:2.51558
# [37]#011train-rmse:2.53554#011validation-rmse:2.51351
# [38]#011train-rmse:2.53147#011validation-rmse:2.51004
# [39]#011train-rmse:2.53027#011validation-rmse:2.50895
# [40]#011train-rmse:2.52923#011validation-rmse:2.50799
# [41]#011train-rmse:2.52479#011validation-rmse:2.50486
# [42]#011train-rmse:2.52067#011validation-rmse:2.50192
# [43]#011train-rmse:2.51739#011validation-rmse:2.49953
# [44]#011train-rmse:2.51429#011validation-rmse:2.49695
# [45]#011train-rmse:2.51342#011validation-rmse:2.49692
# [46]#011train-rmse:2.51179#011validation-rmse:2.49567
# [47]#011train-rmse:2.51034#011validation-rmse:2.49532
# [48]#011train-rmse:2.50969#011validation-rmse:2.49482
# [49]#011train-rmse:2.50758#011validation-rmse:2.49356
# [50]#011train-rmse:2.50716#011validation-rmse:2.49320
# [51]#011train-rmse:2.50602#011validation-rmse:2.49289
# [52]#011train-rmse:2.50448#011validation-rmse:2.49288
# [53]#011train-rmse:2.50210#011validation-rmse:2.49091
# [54]#011train-rmse:2.50106#011validation-rmse:2.49035
# [55]#011train-rmse:2.50081#011validation-rmse:2.49014
# [56]#011train-rmse:2.49872#011validation-rmse:2.48888
# [57]#011train-rmse:2.49706#011validation-rmse:2.48921
#
# 2025-08-08 21:30:01 Uploading - Uploading generated training model[58]#011train-rmse:2.49620#011validation-rmse:2.48912
# [59]#011train-rmse:2.49553#011validation-rmse:2.48888
# [60]#011train-rmse:2.49382#011validation-rmse:2.48880
# [61]#011train-rmse:2.49363#011validation-rmse:2.48870
# [62]#011train-rmse:2.49342#011validation-rmse:2.48864
# [63]#011train-rmse:2.49239#011validation-rmse:2.48917
# [64]#011train-rmse:2.49146#011validation-rmse:2.48925
# [65]#011train-rmse:2.49124#011validation-rmse:2.48918
# [66]#011train-rmse:2.49111#011validation-rmse:2.48909
# [67]#011train-rmse:2.49024#011validation-rmse:2.48892
# [68]#011train-rmse:2.48940#011validation-rmse:2.48823
# [69]#011train-rmse:2.48901#011validation-rmse:2.48832
# [70]#011train-rmse:2.48816#011validation-rmse:2.48761
# [71]#011train-rmse:2.48725#011validation-rmse:2.48771
# [72]#011train-rmse:2.48669#011validation-rmse:2.48800
# [73]#011train-rmse:2.48520#011validation-rmse:2.48785
# [74]#011train-rmse:2.48441#011validation-rmse:2.48749
# [75]#011train-rmse:2.48379#011validation-rmse:2.48742
# [76]#011train-rmse:2.48292#011validation-rmse:2.48802
# [77]#011train-rmse:2.48234#011validation-rmse:2.48800
# [78]#011train-rmse:2.48214#011validation-rmse:2.48776
# [79]#011train-rmse:2.48155#011validation-rmse:2.48754
# [80]#011train-rmse:2.47945#011validation-rmse:2.48624
# [81]#011train-rmse:2.47912#011validation-rmse:2.48619
# [82]#011train-rmse:2.47838#011validation-rmse:2.48610
# [83]#011train-rmse:2.47736#011validation-rmse:2.48570
# [84]#011train-rmse:2.47705#011validation-rmse:2.48604
# [85]#011train-rmse:2.47629#011validation-rmse:2.48665
# [86]#011train-rmse:2.47571#011validation-rmse:2.48654
# [87]#011train-rmse:2.47470#011validation-rmse:2.48644
# [88]#011train-rmse:2.47433#011validation-rmse:2.48642
# [89]#011train-rmse:2.47341#011validation-rmse:2.48608
# [90]#011train-rmse:2.47334#011validation-rmse:2.48605
# [91]#011train-rmse:2.47262#011validation-rmse:2.48603
# [92]#011train-rmse:2.47220#011validation-rmse:2.48603
# [93]#011train-rmse:2.47115#011validation-rmse:2.48530
# [94]#011train-rmse:2.47038#011validation-rmse:2.48512
# [95]#011train-rmse:2.46994#011validation-rmse:2.48514
# [96]#011train-rmse:2.46938#011validation-rmse:2.48490
# [97]#011train-rmse:2.46822#011validation-rmse:2.48446
# [98]#011train-rmse:2.46743#011validation-rmse:2.48509
# [99]#011train-rmse:2.46690#011validation-rmse:2.48564
# [100]#011train-rmse:2.46631#011validation-rmse:2.48567
# [101]#011train-rmse:2.46589#011validation-rmse:2.48566
# [102]#011train-rmse:2.46524#011validation-rmse:2.48569
# [103]#011train-rmse:2.46460#011validation-rmse:2.48526
# [104]#011train-rmse:2.46423#011validation-rmse:2.48529
# [105]#011train-rmse:2.46408#011validation-rmse:2.48518
# [106]#011train-rmse:2.46358#011validation-rmse:2.48585
# [107]#011train-rmse:2.46226#011validation-rmse:2.48504
# [108]#011train-rmse:2.46156#011validation-rmse:2.48577
# [109]#011train-rmse:2.46099#011validation-rmse:2.48555
# [110]#011train-rmse:2.46039#011validation-rmse:2.48559
# [111]#011train-rmse:2.46020#011validation-rmse:2.48559
# [112]#011train-rmse:2.46012#011validation-rmse:2.48555
# [113]#011train-rmse:2.45932#011validation-rmse:2.48554
# [114]#011train-rmse:2.45770#011validation-rmse:2.48417
# [115]#011train-rmse:2.45684#011validation-rmse:2.48371
# [116]#011train-rmse:2.45611#011validation-rmse:2.48369
# [117]#011train-rmse:2.45568#011validation-rmse:2.48377
# [118]#011train-rmse:2.45454#011validation-rmse:2.48378
# [119]#011train-rmse:2.45387#011validation-rmse:2.48378
# [120]#011train-rmse:2.45342#011validation-rmse:2.48384
# [121]#011train-rmse:2.45278#011validation-rmse:2.48390
# [122]#011train-rmse:2.45142#011validation-rmse:2.48375
# [123]#011train-rmse:2.45114#011validation-rmse:2.48382
# [124]#011train-rmse:2.45077#011validation-rmse:2.48399
# [125]#011train-rmse:2.45070#011validation-rmse:2.48394
# [126]#011train-rmse:2.45004#011validation-rmse:2.48415
# [127]#011train-rmse:2.44935#011validation-rmse:2.48403
# [128]#011train-rmse:2.44877#011validation-rmse:2.48439
# [129]#011train-rmse:2.44838#011validation-rmse:2.48456
# [130]#011train-rmse:2.44791#011validation-rmse:2.48456
# [131]#011train-rmse:2.44763#011validation-rmse:2.48473
# [132]#011train-rmse:2.44705#011validation-rmse:2.48478
# [133]#011train-rmse:2.44635#011validation-rmse:2.48474
# [134]#011train-rmse:2.44546#011validation-rmse:2.48515
# [135]#011train-rmse:2.44452#011validation-rmse:2.48507
# [136]#011train-rmse:2.44401#011validation-rmse:2.48532
# [137]#011train-rmse:2.44383#011validation-rmse:2.48533
# [138]#011train-rmse:2.44319#011validation-rmse:2.48590
# [139]#011train-rmse:2.44307#011validation-rmse:2.48586
# [140]#011train-rmse:2.44298#011validation-rmse:2.48585
# [141]#011train-rmse:2.44210#011validation-rmse:2.48534
#
# 2025-08-08 21:30:14 Completed - Training job completed
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2025-08-08-21-30-44-474
# Training seconds: 160
# Billable seconds: 160
# 2025-08-08 21:30:45 Starting - Starting the training job...
# 2025-08-08 21:30:59 Starting - Preparing the instances for training...
# 2025-08-08 21:31:22 Downloading - Downloading input data...
# 2025-08-08 21:32:08 Downloading - Downloading the training image......
# 2025-08-08 21:33:09 Training - Training image download completed. Training in progress../miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2025-08-08 21:33:12.308 ip-10-0-106-105.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-08-08 21:33:12.338 ip-10-0-106-105.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-08-08:21:33:12:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-08-08:21:33:12:INFO] Failed to parse hyperparameter eval_metric value auc to Json.
# Returning the value itself
# [2025-08-08:21:33:12:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2025-08-08:21:33:12:INFO] No GPUs detected (normal if no gpus installed)
# [2025-08-08:21:33:12:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-08-08:21:33:12:INFO] Determined 0 GPU(s) available on the instance.
# [2025-08-08:21:33:12:INFO] Determined delimiter of CSV input is ','
# [2025-08-08:21:33:12:INFO] Determined delimiter of CSV input is ','
# [2025-08-08:21:33:12:INFO] File path /opt/ml/input/data/train of input files
# [2025-08-08:21:33:12:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2025-08-08:21:33:12:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv-8657977589034020648
# [2025-08-08:21:33:12:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2025-08-08:21:33:12:INFO] Determined delimiter of CSV input is ','
# [2025-08-08:21:33:12:INFO] File path /opt/ml/input/data/validation of input files
# [2025-08-08:21:33:12:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [
# [325]#011train-auc:0.94180#011validation-auc:0.93187
# [326]#011train-auc:0.94180#011validation-auc:0.93187
# [327]#011train-auc:0.94184#011validation-auc:0.93188
# [328]#011train-auc:0.94187#011validation-auc:0.93190
# [329]#011train-auc:0.94189#011validation-auc:0.93191
# [330]#011train-auc:0.94195#011validation-auc:0.93193
# [331]#011train-auc:0.94198#011validation-auc:0.93192
# [332]#011train-auc:0.94202#011validation-auc:0.93190
# [333]#011train-auc:0.94202#011validation-auc:0.93190
# [334]#011train-auc:0.94203#011validation-auc:0.93191
# [335]#011train-auc:0.94206#011validation-auc:0.93190
# [336]#011train-auc:0.94212#011validation-auc:0.93190
# [337]#011train-auc:0.94214#011validation-auc:0.93189
# [338]#011train-auc:0.94215#011validation-auc:0.93189
# [339]#011train-auc:0.94220#011validation-auc:0.93192
# [340]#011train-auc:0.94221#011validation-auc:0.93192
# [341]#011train-auc:0.94227#011validation-auc:0.93191
# [342]#011train-auc:0.94235#011validation-auc:0.93189
# [343]#011train-auc:0.94236#011validation-auc:0.93187
# [344]#011train-auc:0.94238#011validation-auc:0.93186
# [345]#011train-auc:0.94245#011validation-auc:0.93187
# [346]#011train-auc:0.94250#011validation-auc:0.93188
# [347]#011train-auc:0.94252#011validation-auc:0.93187
# [348]#011train-auc:0.94254#011validation-auc:0.93189
# [349]#011train-auc:0.94254#011validation-auc:0.93189
# [350]#011train-auc:0.94258#011validation-auc:0.93189
# [351]#011train-auc:0.94263#011validation-auc:0.93184
# [352]#011train-auc:0.94264#011validation-auc:0.93184
# [353]#011train-auc:0.94271#011validation-auc:0.93186
# [354]#011train-auc:0.94274#011validation-auc:0.93186
#
# 2025-08-08 21:34:47 Uploading - Uploading generated training model
# 2025-08-08 21:34:47 Completed - Training job completed
# Training seconds: 205
# Billable seconds: 205

# %%
from sagemaker.deserializers import JSONDeserializer
from sagemaker.serializers import CSVSerializer

reg_ep = "xgb-taxi-reg-poc"
cls_ep = "xgb-taxi-cls-poc"

reg_pred = reg_est.deploy(1, "ml.m5.large", endpoint_name=reg_ep)
cls_pred = cls_est.deploy(1, "ml.m5.large", endpoint_name=cls_ep)
for p in (reg_pred, cls_pred):
    p.serializer = CSVSerializer()
    p.deserializer = JSONDeserializer()
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2025-08-08-21-36-32-111
# INFO:sagemaker:Creating endpoint-config with name xgb-taxi-reg-poc
# INFO:sagemaker:Creating endpoint with name xgb-taxi-reg-poc
# ------!
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2025-08-08-21-40-04-320
# INFO:sagemaker:Creating endpoint-config with name xgb-taxi-cls-poc
# INFO:sagemaker:Creating endpoint with name xgb-taxi-cls-poc
# ------!

# %%
import math
from sklearn.metrics import (mean_squared_error, mean_absolute_error, r2_score,
                             accuracy_score, precision_score, recall_score, f1_score, roc_auc_score)

def predict_batches(predictor, X, bs=500):
    preds=[]
    for i in range(0, len(X), bs):
        payload = "\n".join([",".join(map(str,row)) for row in X.iloc[i:i+bs].values])
        out = predictor.predict(payload)
        preds.extend([r["score"] for r in out["predictions"]])
    return np.array(preds, float)

# Regression
y_reg_pred = predict_batches(reg_pred, X_test)
rmse = math.sqrt(mean_squared_error(y_reg_test, y_reg_pred))
mae  = mean_absolute_error(y_reg_test, y_reg_pred)
mape = float(np.mean(np.where(y_reg_test!=0, np.abs((y_reg_test-y_reg_pred)/y_reg_test), 0))) * 100.0
r2   = r2_score(y_reg_test, y_reg_pred)
baseline_rmse = math.sqrt(mean_squared_error(y_reg_test, np.full_like(y_reg_test.values, y_reg_train.mean())))
improve_pct = (1 - rmse / baseline_rmse) * 100

reg_metrics = {
    "n_test": int(len(y_reg_test)),
    "rmse": rmse, "mae": mae, "mape_pct": mape, "r2": r2,
    "baseline_rmse": baseline_rmse, "rmse_improvement_vs_baseline_pct": improve_pct
}

# Classification
y_cls_proba = predict_batches(cls_pred, X_test)
y_cls_pred  = (y_cls_proba >= 0.5).astype(int)
acc  = accuracy_score(y_cls_test, y_cls_pred)
prec = precision_score(y_cls_test, y_cls_pred, zero_division=0)
rec  = recall_score(y_cls_test, y_cls_pred, zero_division=0)
f1   = f1_score(y_cls_test, y_cls_pred, zero_division=0)
auc  = roc_auc_score(y_cls_test, y_cls_proba)

cls_metrics = {
    "n_test": int(len(y_cls_test)),
    "accuracy": acc, "precision": prec, "recall": rec, "f1": f1, "auc": auc
}

reg_metrics, cls_metrics
# Out:
# ({'n_test': 73542,
#   'rmse': 2.560447565535145,
#   'mae': 1.297054596593154,
#   'mape_pct': 79.31955552765936,
#   'r2': 0.6541359333056419,
#   'baseline_rmse': 4.3537700057090305,
#   'rmse_improvement_vs_baseline_pct': 41.19010507726246},
#  {'n_test': 73542,
#   'accuracy': 0.9541758450953197,
#   'precision': 0.9440852993031651,
#   'recall': 0.9992890784679641,
#   'f1': 0.9709031255396304,
#   'auc': 0.9299152968185095})

# %%
import json
metrics = {"features_order": FEATURES, "regression": reg_metrics, "classification": cls_metrics}

metrics_key = f"{ARTIFACTS_PREFIX}/metrics/metrics.json"
s3.put_object(Bucket=S3_BUCKET, Key=metrics_key, Body=json.dumps(metrics, indent=2).encode())
print("Saved metrics:", f"s3://{S3_BUCKET}/{metrics_key}")

# Small peek files
sample_reg = X_test.head(10).copy()
sample_reg["actual_tip"] = y_reg_test.head(10).values
sample_reg["pred_tip"] = y_reg_pred[:10]
s3.put_object(Bucket=S3_BUCKET, Key=f"{ARTIFACTS_PREFIX}/predictions/reg_sample.csv",
              Body=sample_reg.to_csv(index=False).encode())

sample_cls = X_test.head(10).copy()
sample_cls["actual_is_tipped"] = y_cls_test.head(10).values
sample_cls["prob_is_tipped"]   = y_cls_proba[:10]
sample_cls["pred_is_tipped"]   = (y_cls_proba[:10] >= 0.5).astype(int)
s3.put_object(Bucket=S3_BUCKET, Key=f"{ARTIFACTS_PREFIX}/predictions/cls_sample.csv",
              Body=sample_cls.to_csv(index=False).encode())

# Clean up endpoints to stop costs
reg_pred.delete_endpoint()
cls_pred.delete_endpoint()
# Out:
# INFO:sagemaker:Deleting endpoint configuration with name: xgb-taxi-reg-poc
# Saved metrics: s3://genai-taxi-curated-poc/sagemaker/xgb-taxi/metrics/metrics.json
# INFO:sagemaker:Deleting endpoint with name: xgb-taxi-reg-poc
# INFO:sagemaker:Deleting endpoint configuration with name: xgb-taxi-cls-poc
# INFO:sagemaker:Deleting endpoint with name: xgb-taxi-cls-poc
